# %%
# %matplotlib notebook
import data_structures as ds
import matplotlib.pyplot as plt
import numpy as np

import ipywidgets as widgets
from IPython.display import display

def circle(diameter, thickness, cell_x, cell_y=None, cell_z=None, steps=60):

    # Check if cell sizes are provided for y and z. Otherwise set to length
    # in x, assuming cubes.
    if cell_y is None:
        cell_y = cell_x
    if cell_z is None:
        cell_z = cell_x

xval = []
yval=[]
n=48

xm = 1
ym = 2
r = 1

for i in range(n+1):
    # Increments of angle phi.    
    phi = (2*np.pi) * (1/n)*i
    
    # Parametric circle.
    x = xm + r * np.cos(phi)
    y = ym + r * np.sin(phi)

    # Check
    radius = x**2 + y**2
    
#     print(x, y, radius)
    xval.append(x)
    yval.append(y)

# %%
plt.figure(figsize=[8, 8])
plt.plot(xval, yval)

# plt.xlim(-1.2, 1.2)
# plt.ylim(-1.2, 1.2)
plt.grid()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# Within a given raster, find cells that are touched by the line and collect these cells.

# Define cell size
cell_x = 0.1
cell_y = 0.1

# %%
# %matplotlib notebook
from ipywidgets import *
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi)
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
line, = ax.plot(x, np.sin(x))

def update(w = 1.0):
    line.set_ydata(np.sin(w * x))
    fig.canvas.draw()

interact(update);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def plot_data(n):
    xval = []
    yval=[]
    for i in range(n):
        phi = (1/n*i)
        # 1 = x2 + y2 -> y = sqrt(1-x2)
        x = np.sqrt(1-phi**2)
        xval.append(x)
        yval.append(phi)

    plt.figure(figsize=[8, 8])
    plt.plot(xval, yval)

    plt.xlim(0, 1.2)
    plt.ylim(0, 1.2)
    plt.grid()

    plt.show()

interact(plot_data, n=(0, 50));
